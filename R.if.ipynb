# %%
x<-5
if(x>=0){
    print('Positive Number')
}
# Out:
# [1] "Positive Number"

# %%
x<-5
if(x>=0){
    print('Positive Number')
}
print('End of a Program')
# Out:
# [1] "Positive Number"
# [1] "End of a Program"

# %%
x<- -2
if(x>=0){
    print('Positive Number')
}
print('End of a Program')
# Out:
# [1] "End of a Program"
